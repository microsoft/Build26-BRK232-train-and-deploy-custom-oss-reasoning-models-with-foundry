# %% [markdown]
# <style>
# .exact-shot {
#   max-width: 1280px;
#   margin: 0 auto;
#   background: #f7f5ef !important;
#   color: #020617 !important;
#   font-family: 'Segoe UI', -apple-system, BlinkMacSystemFont, Roboto, Arial, sans-serif;
#   line-height: 1.42;
#   padding: 24px 30px 30px;
#   border-radius: 0;
# }
# .exact-shot * { box-sizing: border-box; }
# .exact-hero {
#   background: #111827 !important;
#   color: #ffffff !important;
#   border-radius: 11px;
#   padding: 19px 26px 18px;
#   min-height: 88px;
#   margin: 0 0 21px;
# }
# .exact-kicker {
#   color: #ded6c8 !important;
#   font-size: 11px;
#   font-weight: 850;
#   letter-spacing: .08em;
#   text-transform: uppercase;
#   margin-bottom: 14px;
# }
# .exact-hero h1 {
#   color: #ffffff !important;
#   font-size: 33px;
#   line-height: 1.05;
#   margin: 0;
#   font-weight: 850;
#   letter-spacing: .1px;
# }
# .exact-band {
#   background: #111827 !important;
#   color: #ffffff !important;
#   border-radius: 7px;
#   min-height: 46px;
#   padding: 8px 18px;
#   margin: 0 0 14px;
#   display: flex;
#   align-items: center;
#   justify-content: center;
# }
# .exact-band h2 {
#   color: #ffffff !important;
#   font-size: 24px;
#   line-height: 1.1;
#   margin: 0;
#   font-weight: 850;
#   text-align: center;
# }
# .exact-panel {
#   background: #ffffff !important;
#   color: #020617 !important;
#   border: 1px solid #ded6c8;
#   border-radius: 10px;
#   padding: 26px 26px 13px;
#   margin: 0 0 27px;
# }
# .exact-idea-row {
#   display: flex;
#   align-items: baseline;
#   gap: 24px;
#   margin: 0 0 22px;
#   color: #020617 !important;
# }
# .exact-idea-row b {
#   font-size: 24px;
#   font-weight: 850;
#   white-space: nowrap;
# }
# .exact-idea-row span {
#   font-size: 23px;
#   color: #020617 !important;
# }
# .exact-cards3 {
#   display: grid;
#   grid-template-columns: repeat(3, 1fr);
#   gap: 25px;
#   margin: 0 0 14px;
# }
# .exact-card {
#   background: #ffffff !important;
#   color: #020617 !important;
#   border: 1px solid #ded6c8;
#   border-radius: 8px;
#   padding: 17px 17px 13px;
#   min-height: 76px;
# }
# .exact-card b {
#   display: block;
#   color: #020617 !important;
#   font-size: 18px;
#   line-height: 1.1;
#   margin: 0 0 8px;
#   font-weight: 850;
# }
# .exact-card p {
#   color: #020617 !important;
#   font-size: 16px;
#   line-height: 1.28;
#   margin: 0;
# }
# .exact-card.gray { background: #fbfaf7 !important; border-left: 4px solid #64748b; }
# .exact-card.blue { background: #fbfaf7 !important; border-color: #ded6c8; border-left: 4px solid #6b7280; }
# .exact-card.purple { background: #fbfaf7 !important; border-color: #ded6c8; border-left: 4px solid #374151; }
# .exact-card.focus { background: #ffffff !important; border: 2px solid #111827; box-shadow: 0 0 0 3px #ded6c8; }
# .exact-remember {
#   color: #020617 !important;
#   font-size: 16px;
#   margin: 0;
# }
# .exact-remember b {
#   font-weight: 850;
#   margin-right: 22px;
# }
# .exact-code {
#   color: #111827 !important;
#   font-family: Consolas, 'Cascadia Mono', monospace;
#   font-size: 15px;
#   background: #f4f1ea !important;
#   padding: 1px 6px;
#   border-radius: 3px;
# }
# </style>
#
# <div class="exact-shot">
#   <div class="exact-hero">
#     <div class="exact-kicker">BUILD 2026 DEMO</div>
#     <h1>Retail Customer Agent Grader Test Bed</h1>
#   </div>
#
#   <div class="exact-band"><h2>Grader Robustness Demo</h2></div>
#
#   <div class="exact-panel">
#     <p class="exact-idea-row"><b>10-second idea:</b><span>Run the original grader, then the fixed grader, on the same generated rollout fixture.</span></p>
#     <div class="exact-cards3">
#       <div class="exact-card gray"><b>Original</b><p><span class="exact-code">grader()</span> shows scores when generated text outside <span class="exact-code">output_text</span> is missed.</p></div>
#       <div class="exact-card blue focus"><b>Fix</b><p><span class="exact-code">grader_fixed()</span> reads <span class="exact-code">final_response</span>, <span class="exact-code">response</span>, and metadata text.</p></div>
#       <div class="exact-card purple"><b>Proof</b><p>Perfect generated-schema rows improve from <span class="exact-code">0.300</span> to <span class="exact-code">1.000</span>.</p></div>
#     </div>
#     <p class="exact-remember"><b>Remember:</b> This demonstrates grader robustness to rollout schema shape, not a change in the model answers.</p>
#   </div>
# </div>

# %% [markdown]
# <div class="exact-shot">
#   <div class="exact-band"><h2>Part 1 - Load the Demo Functions</h2></div>
#   <div class="exact-panel">
#     <p class="exact-idea-row"><b>Goal:</b><span>Keep the notebook clean and import the prepared grader demo scripts.</span></p>
#     <div class="exact-cards3">
#       <div class="exact-card gray"><b>Scripts</b><p><span class="exact-code">grader_demo.py</span> and <span class="exact-code">grader_eval_helpers.py</span></p></div>
#       <div class="exact-card blue focus"><b>Functions</b><p>Load <span class="exact-code">grader()</span> and <span class="exact-code">grader_fixed()</span>.</p></div>
#       <div class="exact-card purple"><b>Fixture</b><p>Use <span class="exact-code">local_eval_samples_10.jsonl</span> from the experimentation folder.</p></div>
#     </div>
#   </div>
# </div>

# %%
import importlib.util
import sys
from pathlib import Path

demo_dir = Path.cwd() / "post-training-experimentation"
if not demo_dir.exists():
    demo_dir = Path.cwd().parent / "post-training-experimentation"

if str(demo_dir) not in sys.path:
    sys.path.insert(0, str(demo_dir))

spec = importlib.util.spec_from_file_location("grader_demo", demo_dir / "grader_demo.py")
grader_demo = importlib.util.module_from_spec(spec)
sys.modules["grader_demo"] = grader_demo
spec.loader.exec_module(grader_demo)

grader = grader_demo.grader
grader_fixed = grader_demo.grader_fixed

# %% [markdown]
# <div class="exact-shot">
#   <div class="exact-band"><h2>Part 2 - Run the Original Grader</h2></div>
#   <div class="exact-panel">
#     <p class="exact-idea-row"><b>Goal:</b><span>Show the baseline behavior before the generated-text fallback is enabled.</span></p>
#     <div class="exact-cards3">
#       <div class="exact-card gray"><b>Original</b><p><span class="exact-code">grader()</span> simulates the fallback line commented out.</p></div>
#       <div class="exact-card blue focus"><b>What it sees</b><p>Rows without top-level <span class="exact-code">output_text</span> look empty to the grader.</p></div>
#       <div class="exact-card purple"><b>Result</b><p>The score mostly comes from tool coverage, not the customer-facing answer.</p></div>
#     </div>
#   </div>
# </div>

# %%
original_scores = grader()
# Out:
# Original grader scores
# Average reward: 0.199
# sample_idx  scenario                              score
# 0          perfect_exchange                     0.300
# 1          wrong_refund_amount_missing_submit   0.279
# 2          denial_wrong_reason                  0.300
# 3          clarification_marker_without_order_a 0.100
# 4          missing_tools_and_amount             0.000
# 5          empty_cancellation_response          0.000
# 6          invalid_tool_and_wrong_amount        0.130
# 7          tool_spam_with_correct_text          0.116
# 8          low_wrong_item_and_action            0.182
# 9          partial_multi_item_resolution        0.285
# 10         perfect_refund_final_response_only   0.300
# 11         perfect_cancel_response_only         0.300
# 12         perfect_store_credit_metadata_text   0.300

# %% [markdown]
# <div class="exact-shot">
#   <div class="exact-band"><h2>Part 3 - Run the Fixed Grader</h2></div>
#   <div class="exact-panel">
#     <p class="exact-idea-row"><b>Goal:</b><span>Show the same rows after the grader reads generated rollout text fields.</span></p>
#     <div class="exact-cards3">
#       <div class="exact-card gray"><b>Fixed</b><p><span class="exact-code">grader_fixed()</span> enables the generated-text fallback.</p></div>
#       <div class="exact-card blue focus"><b>Improvement</b><p>Rows stored in <span class="exact-code">final_response</span> improve from <span class="exact-code">0.300</span> to <span class="exact-code">1.000</span>.</p></div>
#       <div class="exact-card purple"><b>Cause</b><p>The grader now checks the fields used by generated rollout exports, not only <span class="exact-code">output_text</span>.</p></div>
#     </div>
#     <p class="exact-idea-row"><b>Fix in the grader:</b><span>Add fallback reads in <span class="exact-code">_extract_output_text()</span> so generated answers are visible to the parser.</span></p>
#     <pre style="background:#f8fafc; color:#0f172a; border:2px solid #334155; border-radius:8px; padding:14px 16px; font-family:Consolas, 'Cascadia Mono', monospace; font-size:15px; line-height:1.45; overflow:auto;"><code style="color:#0f172a;">def _extract_output_text(sample: dict, item: dict) -> str:
#     if isinstance(sample, dict):
#         v = sample.get("output_text")
# <span style="display:block; background:#ffedd5; color:#7c2d12; border-left:6px solid #ea580c; margin:4px -10px; padding:4px 8px; font-weight:800; box-shadow:0 0 0 1px rgba(124,45,18,0.25) inset;">        v = v or sample.get("final_response") or sample.get("response") or (sample.get("metadata") or {}).get("output_text")  # FIX</span>        if isinstance(v, str) and v.strip():
#             return v</code></pre>
#   </div>
# </div>

# %%
fixed_scores = grader_fixed()
# Out:
# Fixed grader scores
# Average reward: 0.648
# sample_idx  scenario                              original  fixed   delta
# 0          perfect_exchange                     0.300     1.000   +0.700
# 1          wrong_refund_amount_missing_submit   0.279     0.700   +0.421
# 2          denial_wrong_reason                  0.300     0.700   +0.400
# 3          clarification_marker_without_order_a 0.100     0.400   +0.300
# 4          missing_tools_and_amount             0.000     0.500   +0.500
# 5          empty_cancellation_response          0.000     0.000   +0.000
# 6          invalid_tool_and_wrong_amount        0.130     0.530   +0.400
# 7          tool_spam_with_correct_text          0.116     0.650   +0.534
# 8          low_wrong_item_and_action            0.182     0.272   +0.090
# 9          partial_multi_item_resolution        0.285     0.673   +0.388
# 10         perfect_refund_final_response_only   0.300     1.000   +0.700
# ...

# %% [markdown]
# <div class="exact-shot">
#   <!-- <div class="exact-band"><h2>Close - Explain the Improvement</h2></div> -->
#   <div class="exact-panel">
#     <p class="exact-idea-row"><b></b><span>The fix does not make a bad answer look good; it lets the grader see the answer that was already generated.</span></p>
#     <div class="exact-cards3">
#       <div class="exact-card gray"><b>Before</b><p>For sample <span class="exact-code">10</span>, the original grader sees <span class="exact-code">&lt;empty text&gt;</span> and parses no actions.</p></div>
#       <div class="exact-card blue focus"><b>After</b><p>The fixed grader reads <span class="exact-code">final_response</span>, parses the refund action, and scores <span class="exact-code">1.000</span>.</p></div>
#       <div class="exact-card purple"><b>Cause</b><p>The robustness change is a generated-text fallback in <span class="exact-code">_extract_output_text()</span>.</p></div>
#     </div>
#   </div>
# </div>
